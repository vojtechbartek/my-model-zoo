# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys
import os
import matplotlib.pyplot as plt

from ..models.classification.perceptron import Perceptron
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/vojtechbartek/Documents/my-model-zoo/src/notebooks/perceptron.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/src/notebooks/perceptron.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import os
#       <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/src/notebooks/perceptron.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/src/notebooks/perceptron.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> from ..models.classification.perceptron import Perceptron
#
# ImportError: attempted relative import with no known parent package

# %%
dataset_file_path = '../data/classification/test.csv'
data = np.genfromtxt(dataset_file_path, delimiter=',', skip_header=1)
X = data[:, :-1]
y = data[:, -1].reshape(-1,1)
print(X.shape)
print(y.shape)
# Out:
# (12, 2)
# (12, 1)

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y.flatten(), palette='coolwarm')
# Out:
# <AxesSubplot: >

# %%
classifier = Perceptron()
classifier = classifier.fit(X,y, 3000)
print(classifier.last_iteration)
print(classifier.w)
print(classifier.b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/vojtechbartek/Documents/my-model-zoo/notebooks/perceptron.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/notebooks/perceptron.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> classifier = Perceptron()
#       <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/notebooks/perceptron.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> classifier = classifier.fit(X,y, 3000)
# ----> <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/notebooks/perceptron.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> print(classifier.last_iteration)
#       <a href='vscode-notebook-cell:/Users/vojtechbartek/Documents/my-model-zoo/notebooks/perceptron.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> print(classifier.w)
# ...

# %%
w = classifier.theta[:-1]
b = classifier.theta[-1]

xs = np.linspace(-10,10,100)
ys = -w[0]/w[1] * xs -b/w[1]

plt.plot(xs, ys, color='black', label='Decision Boundary')
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y.flatten(), palette='coolwarm')
plt.show()
